# %% [markdown]
# <a href="https://colab.research.google.com/github/archit-55/computer_vision/blob/master/comp_vision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
print(cv2.__version__)
# Out:
# 3.4.3

# %%
img=cv2.imread("dog.jpeg")

# %%
img
# Out:
# array([[[ 20,  40,  23],
#         [ 20,  40,  23],
#         [ 20,  40,  23],
#         ...,
#         [ 10,  29,  14],
#         [ 10,  29,  14],
#         [ 10,  29,  14]],
#
#        [[ 20,  40,  23],
#         [ 20,  40,  23],
#         [ 20,  40,  23],
#         ...,
#         [ 10,  29,  14],
#         [ 10,  29,  14],
#         [ 10,  29,  14]],
#
#        [[ 20,  40,  23],
#         [ 20,  40,  23],
#         [ 20,  40,  23],
#         ...,
#         [ 10,  29,  14],
#         [ 10,  29,  14],
#         [ 10,  29,  14]],
#
#        ...,
#
#        [[ 69, 178, 131],
#         [ 69, 178, 131],
#         [ 69, 178, 131],
#         ...,
#         [ 57, 159, 115],
#         [ 57, 159, 115],
#         [ 57, 159, 115]],
#
#        [[ 69, 178, 131],
#         [ 69, 178, 131],
#         [ 69, 178, 131],
#         ...,
#         [ 57, 159, 115],
#         [ 57, 159, 115],
#         [ 57, 159, 115]],
#
#        [[ 69, 178, 131],
#         [ 69, 178, 131],
#         [ 69, 178, 131],
# ...

# %%
#   print shape
img.shape
# Out:
# (606, 800, 3)

# %%
#   type of image
type(img)
# Out:
# numpy.ndarray

# %%
#  to display image
plt.imshow(img)

# %%
#  wait for window to close
#cv2.waitkey(0)       # milli/micro seconds

# %%
img1=cv2.imread("dog.jpeg",1)   # for black and white
img2=cv2.imread("dog.jpeg",0)   # for coloured
img3=cv2.imread("dog.jpeg",-1)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
plt.imshow(img3)
